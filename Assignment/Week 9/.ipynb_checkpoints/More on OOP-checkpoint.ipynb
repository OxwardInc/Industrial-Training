# %%
class Item:
    def __init__(self):
        print('I am created')
        
    def calculate_total_price(self, x, y):
        return x * y

item_1 = Item()
item_1.name = 'Phone'
item_1.price = 100
item_1.quantity = 5
print(item_1.calculate_total_price(item_1.price, item_1.quantity))

item_2 = Item()
item_2.name = 'Laptop'
item_2.price = 1000
item_2.quantity = 3
print(item_2.calculate_total_price(item_2.price, item_2.quantity))
# Out:
# I am created
# 500
# I am created
# 3000

# %%
class Item:
    def __init__(self, name, price, quantity):
        print(f'An instance created: {name}')
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self, x, y):
        return x * y

item_1 = Item('Phone', 100, 5)
print(item_1.calculate_total_price(item_1.price, item_1.quantity))

item_2 = Item('Laptop', 1000, 3)
print(item_2.calculate_total_price(item_2.price, item_2.quantity))

print(item_1.name)
print(item_2.name)
print(item_1.price)
print(item_2.price)
print(item_1.quantity)
print(item_2.quantity)
# Out:
# An instance created: Phone
# 500
# An instance created: Laptop
# 3000
# Phone
# Laptop
# 100
# 1000
# 5
# 3

# %%
class Item:
    def __init__(self, name, price, quantity = 0):
        print(f'An instance created: {name}')
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self, x, y):
        return x * y

item_1 = Item('Phone', 100)
print(item_1.calculate_total_price(item_1.price, item_1.quantity))

item_2 = Item('Laptop', 1000)
print(item_2.calculate_total_price(item_2.price, item_2.quantity))

print(item_1.name)
print(item_2.name)
print(item_1.price)
print(item_2.price)
print(item_1.quantity)
print(item_2.quantity)
# Out:
# An instance created: Phone
# 0
# An instance created: Laptop
# 0
# Phone
# Laptop
# 100
# 1000
# 0
# 0

# %%
class Item:
    def __init__(self, name, price, quantity = 0):
        print(f'An instance created: {name}')
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self):
        return self.price * self.quantity

item_1 = Item('Phone', 100, 1)

item_2 = Item('Laptop', 1000, 3)

print(item_1.calculate_total_price())
print(item_2.calculate_total_price())
# Out:
# An instance created: Phone
# An instance created: Laptop
# 100
# 3000

# %%
class Item:
    def __init__(self, name, price, quantity = 0):
        print(f'An instance created: {name}')
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self):
        return self.price * self.quantity

item_1 = Item('Phone', '100', 1)

item_2 = Item('Laptop', '1000', 3)

print(item_1.calculate_total_price())
print(item_2.calculate_total_price())
# Out:
# An instance created: Phone
# An instance created: Laptop
# 100
# 100010001000

# %%
class Item:
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

item_1 = Item('Phone', 100, -1)

item_2 = Item('Laptop', 1000, -3)

print(item_1.calculate_total_price())
print(item_2.calculate_total_price())
# Out:
# An instance created: Phone
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 17
#      14     def calculate_total_price(self):
#      15         return self.price * self.quantity
# ---> 17 item_1 = Item('Phone', 100, -1)
#      19 item_2 = Item('Laptop', 1000, -3)
#      21 print(item_1.calculate_total_price())
#
# Cell In[12], line 6, in Item.__init__(self, name, price, quantity)
#       4 #Run validations to the recieved arguments
#       5 assert price >= 0, f'Price {price} is not greater than or equal to zero'
# ----> 6 assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'
#       8 #Assign to self object
#       9 self.name = name
#
# AssertionError: Quantity -1 is not greater than or equal to zero

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

item_1 = Item('Phone', 100, 1)

item_2 = Item('Laptop', 1000, 3)

print(item_1.calculate_total_price())
print(item_2.calculate_total_price())
print(Item.pay_rate)
print(item_2.pay_rate)
print(item_1.pay_rate)
# Out:
# An instance created: Phone
# An instance created: Laptop
# 100
# 3000
# 0.8
# 0.8
# 0.8

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

item_1 = Item('Phone', 100, 1)

item_2 = Item('Laptop', 1000, 3)

print(Item.__dict__) # All the attributes for class level
print(item_1.__dict__) # All the attributes for instance level
# Out:
# An instance created: Phone
# An instance created: Laptop
# {'__module__': '__main__', 'pay_rate': 0.8, '__init__': <function Item.__init__ at 0x00000160E03E7740>, 'calculate_total_price': <function Item.calculate_total_price at 0x00000160E03E77E0>, '__dict__': <attribute '__dict__' of 'Item' objects>, '__weakref__': <attribute '__weakref__' of 'Item' objects>, '__doc__': None}
# {'name': 'Phone', 'price': 100, 'quantity': 1}

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

item_1 = Item('Phone', 100, 1)
item_1.apply_discount()

item_2 = Item('Laptop', 1000, 3)
item_2.pay_rate = 0.7
item_2.apply_discount()

#print(item_1.price)
print(item_2.price)
#print(Item.__dict__) # All the attributes for class level
print(item_2.__dict__) # All the attributes for instance level
# Out:
# An instance created: Phone
# An instance created: Laptop
# 700.0
# {'name': 'Laptop', 'price': 700.0, 'quantity': 3, 'pay_rate': 0.7}

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

item_1 = Item('Phone', 100, 1)
item_2 = Item('Laptop', 1000, 3)
item_3 = Item('Cable', 10, 5)
item_4 = Item('Mouse', 50, 5)
item_5 = Item('Keybord', 75, 5)

for instance in Item.all:
    print(instance.name)
# Out:
# An instance created: Phone
# An instance created: Laptop
# An instance created: Cable
# An instance created: Mouse
# An instance created: Keybord
# Phone
# Laptop
# Cable
# Mouse
# Keybord

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

item_1 = Item('Phone', 100, 1)
item_2 = Item('Laptop', 1000, 3)
item_3 = Item('Cable', 10, 5)
item_4 = Item('Mouse', 50, 5)
item_5 = Item('Keybord', 75, 5)

print(Item.all)
# Out:
# An instance created: Phone
# An instance created: Laptop
# An instance created: Cable
# An instance created: Mouse
# An instance created: Keybord
# [<__main__.Item object at 0x00000160E081B350>, <__main__.Item object at 0x00000160E081B150>, <__main__.Item object at 0x00000160E081BF50>, <__main__.Item object at 0x00000160E0819D90>, <__main__.Item object at 0x00000160E0819750>]

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    def __repr__(self):
        return "Item"

item_1 = Item('Phone', 100, 1)
item_2 = Item('Laptop', 1000, 3)
item_3 = Item('Cable', 10, 5)
item_4 = Item('Mouse', 50, 5)
item_5 = Item('Keybord', 75, 5)

print(Item.all)
# Out:
# An instance created: Phone
# An instance created: Laptop
# An instance created: Cable
# An instance created: Mouse
# An instance created: Keybord
# [Item, Item, Item, Item, Item]

# %%
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

item_1 = Item('Phone', 100, 1)
item_2 = Item('Laptop', 1000, 3)
item_3 = Item('Cable', 10, 5)
item_4 = Item('Mouse', 50, 5)
item_5 = Item('Keybord', 75, 5)

print(Item.all)
# Out:
# An instance created: Phone
# An instance created: Laptop
# An instance created: Cable
# An instance created: Mouse
# An instance created: Keybord
# [Item('Phone', 100, 1), Item('Laptop', 1000, 3), Item('Cable', 10, 5), Item('Mouse', 50, 5), Item('Keybord', 75, 5)]

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
            print(item)

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

Item.instantiate_from_csv()
# Out:
# {'name': 'Phone', 'price': '100', 'quantity': '1'}
# {'name': 'Laptop', 'price': '1000', 'quantity': '3'}
# {'name': 'Cable', 'price': '10', 'quantity': '5'}
# {'name': 'Mouse', 'price': '50', 'quantity': '5'}
# {'name': 'Keyboard', 'price': '75', 'quantity': '5'}

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
           Item(
               name = item.get('name'),
               price = float(item.get('price')),
               quantity = int(item.get('quantity')),
           )

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

Item.instantiate_from_csv()
print(Item.all)
# Out:
# An instance created: Phone
# An instance created: Laptop
# An instance created: Cable
# An instance created: Mouse
# An instance created: Keyboard
# [Item('Phone', 100.0, 1), Item('Laptop', 1000.0, 3), Item('Cable', 10.0, 5), Item('Mouse', 50.0, 5), Item('Keyboard', 75.8, 5)]

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
           Item(
               name = item.get('name'),
               price = float(item.get('price')),
               quantity = int(item.get('quantity')),
           )

    @staticmethod
    def is_integer(num):
        # We'll count out the floats that are point zero
        # for i.e: 5.0, 10.0
        if isinstance(num, float):
            # Count out the floats that are point zero
            return num.is_integer()

        elif isinstance(num, int):
            return True

        else:
            return False
            

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

print(Item.is_integer(7.0))
print(Item.is_integer(7.5))
# Out:
# True
# False

# %%
# When to use a class method or static method

class Item:
    @staticmethod
    def is_integer(num):
        '''
        This should do something that as a relationship with the class,
        but not something that must be unique per instance
        '''

    @classmethod
    def instantiate_from_something(cls):
        '''
        This should also do something that has a relationship with the class,
        but unfortunately, those are used to manipulate different structures of
        data to instatntiate objects, like we have done with CSV.
        '''

# However, those could be also called from instances.
item1 = Item()
item1.is_integer(5)
item1.instantiate_from_something()

# %%
import csv

class Phone(Item):
    all = []
    def __init__(self, name: str, price: float, quantity = 0, broken_phones = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'
        assert broken_phones >= 0, f'Broken phones {broken_phones} is not greater than or equal to zero'

        
        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        self.broken_phones = broken_phones

        # Actions to execute
        Phone.all.append(self)

phone1 = Phone("jscPhonev10", 500, 5)
phone1.broken_phones = 1
phone2 = Phone("jscPhonev20", 700, 5)
phone2.broken_phones = 1
# Out:
# An instance created: jscPhonev10
# An instance created: jscPhonev20

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
           Item(
               name = item.get('name'),
               price = float(item.get('price')),
               quantity = int(item.get('quantity')),
           )

    @staticmethod
    def is_integer(num):
        # We'll count out the floats that are point zero
        # for i.e: 5.0, 10.0
        if isinstance(num, float):
            # Count out the floats that are point zero
            return num.is_integer()

        elif isinstance(num, int):
            return True

        else:
            return False
            

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

class Phone(Item):
    all = []
    def __init__(self, name: str, price: float, quantity = 0, broken_phones = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'
        assert broken_phones >= 0, f'Broken phones {broken_phones} is not greater than or equal to zero'

        
        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity
        self.broken_phones = broken_phones

        # Actions to execute
        Phone.all.append(self)

phone1 = Phone("jscPhonev10", 500, 5, 1)
print(phone1.calculate_total_price())
phone2 = Phone("jscPhonev20", 700, 5, 1)
print(phone2.calculate_total_price())
# Out:
# An instance created: jscPhonev10
# 2500
# An instance created: jscPhonev20
# 3500

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
           Item(
               name = item.get('name'),
               price = float(item.get('price')),
               quantity = int(item.get('quantity')),
           )

    @staticmethod
    def is_integer(num):
        # We'll count out the floats that are point zero
        # for i.e: 5.0, 10.0
        if isinstance(num, float):
            # Count out the floats that are point zero
            return num.is_integer()

        elif isinstance(num, int):
            return True

        else:
            return False
            

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

class Phone(Item):
    all = []
    def __init__(self, name: str, price: float, quantity = 0, broken_phones = 0):
        
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert broken_phones >= 0, f'Broken phones {broken_phones} is not greater than or equal to zero'

        
        #Assign to self object
        self.broken_phones = broken_phones

        # Actions to execute
        Phone.all.append(self)

phone1 = Phone("jscPhonev10", 500, 5, 1)
print(phone1.calculate_total_price())
phone2 = Phone("jscPhonev20", 700, 5, 1)
#print(phone2.calculate_total_price())
# Out:
# An instance created: jscPhonev10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 72
#      69         Phone.all.append(self)
#      71 phone1 = Phone("jscPhonev10", 500, 5, 1)
# ---> 72 print(phone1.calculate_total_price())
#      73 phone2 = Phone("jscPhonev20", 700, 5, 1)
#      74 #print(phone2.calculate_total_price())
#
# Cell In[49], line 21, in Item.calculate_total_price(self)
#      20 def calculate_total_price(self):
# ---> 21     return self.price * self.quantity
#
# AttributeError: 'Phone' object has no attribute 'price'

# %%
import csv
class Item:
    pay_rate = 0.8 # The pay rate of 20% discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert price >= 0, f'Price {price} is not greater than or equal to zero'
        assert quantity >= 0, f'Quantity {quantity} is not greater than or equal to zero'

        #Assign to self object
        self.name = name
        self.price = price
        self.quantity = quantity

        # Actions to execute
        Item.all.append(self)
        
        
    def calculate_total_price(self):
        return self.price * self.quantity

    def apply_discount(self):
        self.price = self.price * self.pay_rate

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        for item in items:
           Item(
               name = item.get('name'),
               price = float(item.get('price')),
               quantity = int(item.get('quantity')),
           )

    @staticmethod
    def is_integer(num):
        # We'll count out the floats that are point zero
        # for i.e: 5.0, 10.0
        if isinstance(num, float):
            # Count out the floats that are point zero
            return num.is_integer()

        elif isinstance(num, int):
            return True

        else:
            return False
            

    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"

class Phone(Item):
    all = []
    def __init__(self, name: str, price: float, quantity = 0, broken_phones = 0):
        #Call t super function to have access to all attributes/methods
        super().__init__(
            name, price, quantity
        )
        
        print(f'An instance created: {name}')
        #Run validations to the recieved arguments
        assert broken_phones >= 0, f'Broken phones {broken_phones} is not greater than or equal to zero'

        
        #Assign to self object
        self.broken_phones = broken_phones

        # Actions to execute
        Phone.all.append(self)

phone1 = Phone("jscPhonev10", 500, 5, 1)
print(phone1.calculate_total_price())
phone2 = Phone("jscPhonev20", 700, 5, 1)
print(phone2.calculate_total_price())
# Out:
# An instance created: jscPhonev10
# An instance created: jscPhonev10
# 2500
# An instance created: jscPhonev20
# An instance created: jscPhonev20
# 3500
