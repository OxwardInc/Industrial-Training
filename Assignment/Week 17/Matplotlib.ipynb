# %% [markdown]
# ## General Matplotlib Tips

# %% [markdown]
# ### Importiing matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting styles

# %%
plt.style.use('classic')

# %% [markdown]
# ### Show() or No show()? How to Display Your Plots

# %% [markdown]
# #### Ploting from a script

# %%
#------file: matplot.py-------

import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# #### Plotting from an IPython shell

# %%
# %matplotlib
#using matplotlib backend: TkAgg
# Out:
# Using matplotlib backend: <object object at 0x000001D2DE00F5D0>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plotting from an IPython notebook

# %%
# %matplotlib inline

# %%
import numpy as np

x = np.linspace(0, 10, 100)

fig = plt.Figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# ### Saving figures to File

# %%
fig.savefig('my_figre.png')

# %%
# !ls -lh my_figre.png
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image
Image('my_figre.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ## Two Interfaces for the Price of One

# %%
plt.Figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# #### Object-oriented interface

# %%
# First create a grid of plots
# ax will be an array of two Axis objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ## Simple line plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ### Adjusting the Plot: Line Colors and styles

# %%
plt.plot(x, np.sin(x - 0), color= 'blue') # specify color by name
plt.plot(x, np.sin(x - 1), color= 'g')    # specify color by code(rgbcmyk)
plt.plot(x, np.sin(x - 2), color= '0.75') # greyscale between 0 and 1
plt.plot(x, np.sin(x - 3), color= '#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color= (1.0, 0.2, 0.3)) #RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color= 'chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle= 'solid')
plt.plot(x, x + 1, linestyle= 'dashed')
plt.plot(x, x + 2, linestyle= 'dashdot')
plt.plot(x, x + 3, linestyle= 'dotted')

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle = '-') # solid
plt.plot(x, x + 5, linestyle = '--') # dashed
plt.plot(x, x + 6, linestyle = '-.') # dashdot
plt.plot(x, x + 7, linestyle = ':') # dotted

# %%
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r') # dotted red

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
# Out:
# Text(0.5, 1.0, 'A Sine Curve')

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('X')
plt.ylabel('Sin(X)');

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')

plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
        xlabel='x', ylabel='sin(x)',
        title='A simple plot');

# %% [markdown]
# ## Simple Scatter plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ### Scatter plots with plt.plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
            label="marker= '{0}'".format(marker))
        
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-ok'); # line(-), circle marker (o), black(k)

# %%
plt.plot(x, y, '-p', color='gray',
        markersize=15, linewidth=4,
        markerfacecolor='white',
        markeredgecolor='gray',
        markeredgewidth=2)

plt.ylim(-1.2, 1.2);

# %% [markdown]
# ### Scatter plots with plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')

plt.colorbar(); # show the color scale

# %%
from sklearn.datasets import load_iris

iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s = 100 * features[3], c = iris.target, cmap= 'viridis')
        
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# ### plot Versus scatter: A Note on Efficiency

# %% [markdown]
# ## Visualizing Errors

# %% [markdown]
# #### Basic Errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
            ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# #### Continuous Error

# %%
from sklearn.gaussian_process import GaussianProcessRegressor, GaussianProcessClassifier

# %%
# define the model and draw some data

model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# compute the Gaussian Process fit
gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
                                random_state= 100)
                    
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10,  1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE= True)
dyfit = 2 * np.sqrt(MSE) # 2*sigma ~ 95% confidence region
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 8
#       5 ydata = model(xdata)
#       7 # compute the Gaussian Process fit
# ----> 8 gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
#       9                                 random_state= 100)
#      11 gp.fit(xdata[:, np.newaxis], ydata)
#      13 xfit = np.linspace(0, 10,  1000)
#
# NameError: name 'GaussianProcess' is not defined

# %% [markdown]
# ## Density and Color plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Visualizing a Three-Dimensional Function

# %%
def f(x, y):
    np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plt.contour(X, Y, Z, colors='black');
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2924, in contour(data, *args, **kwargs)
#    2922 @_copy_docstring_and_deprecators(Axes.contour)
#    2923 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2924     __ret = gca().contour(
#    2925         *args, **({"data": data} if data is not None else {}), **kwargs
#    2926     )
#    2927     if __ret._A is not None:  # type: ignore[attr-defined]
#    2928         sci(__ret)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:6517, in Axes.contour(self, *args, **kwargs)
#    6508 """
#    6509 Plot contour lines.
#    6510
#    (...)
#    6514 %(contour_doc)s
#    6515 """
#    6516 kwargs['filled'] = False
# -> 6517 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6518 self._request_autoscale_view()
#    6519 return contours
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt.contour(X, Y, Z, 20, cmap='RdGy');
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2924, in contour(data, *args, **kwargs)
#    2922 @_copy_docstring_and_deprecators(Axes.contour)
#    2923 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2924     __ret = gca().contour(
#    2925         *args, **({"data": data} if data is not None else {}), **kwargs
#    2926     )
#    2927     if __ret._A is not None:  # type: ignore[attr-defined]
#    2928         sci(__ret)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:6517, in Axes.contour(self, *args, **kwargs)
#    6508 """
#    6509 Plot contour lines.
#    6510
#    (...)
#    6514 %(contour_doc)s
#    6515 """
#    6516 kwargs['filled'] = False
# -> 6517 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6518 self._request_autoscale_view()
#    6519 return contours
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %%
plt.cm.Accent

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 plt.contourf(X, Y, Z, 20, cmap='RdGy')
#       2 plt.colorbar();
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2935, in contourf(data, *args, **kwargs)
#    2933 @_copy_docstring_and_deprecators(Axes.contourf)
#    2934 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2935     __ret = gca().contourf(
#    2936         *args, **({"data": data} if data is not None else {}), **kwargs
#    2937     )
#    2938     if __ret._A is not None:  # type: ignore[attr-defined]
#    2939         sci(__ret)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:6533, in Axes.contourf(self, *args, **kwargs)
#    6524 """
#    6525 Plot filled contours.
#    6526
#    (...)
#    6530 %(contour_doc)s
#    6531 """
#    6532 kwargs['filled'] = True
# -> 6533 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6534 self._request_autoscale_view()
#    6535 return contours
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
            cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
#       2             cmap='RdGy')
#       3 plt.colorbar()
#       4 plt.axis(aspect='image');
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3343, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3322 @_copy_docstring_and_deprecators(Axes.imshow)
#    3323 def imshow(
#    3324     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3341     **kwargs,
#    3342 ) -> AxesImage:
# -> 3343     __ret = gca().imshow(
#    3344         X,
#    3345         cmap=cmap,
#    3346         norm=norm,
#    3347         aspect=aspect,
#    3348         interpolation=interpolation,
#    3349         alpha=alpha,
#    3350         vmin=vmin,
#    3351         vmax=vmax,
#    3352         origin=origin,
#    3353         extent=extent,
#    3354         interpolation_stage=interpolation_stage,
#    3355         filternorm=filternorm,
#    3356         filterrad=filterrad,
#    3357         resample=resample,
#    3358         url=url,
#    3359         **({"data": data} if data is not None else {}),
#    3360         **kwargs,
#    3361     )
#    3362     sci(__ret)
#    3363     return __ret
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5753 if aspect is not None:
#    5754     self.set_aspect(aspect)
# -> 5756 im.set_data(X)
#    5757 im.set_alpha(alpha)
#    5758 if im.get_clip_path() is None:
#    5759     # image does not already have clipping set, clip to axes patch
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:688, in _ImageBase._normalize_image_array(A)
#     686 A = cbook.safe_masked_invalid(A, copy=True)
#     687 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 688     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     689                     f"converted to float")
#     690 if A.ndim == 3 and A.shape[-1] == 1:
#     691     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# ## Histograms, Binnings, and Density

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)

plt.hist(data);

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 plt.hist(data, bins=30, normed=True, alpha=0.5,
#       2         histtype='stepfilled', color='steelblue',
#       3         edgecolor='none');
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3221, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3196 @_copy_docstring_and_deprecators(Axes.hist)
#    3197 def hist(
#    3198     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3219     BarContainer | Polygon | list[BarContainer | Polygon],
#    3220 ]:
# -> 3221     return gca().hist(
#    3222         x,
#    3223         bins=bins,
#    3224         range=range,
#    3225         density=density,
#    3226         weights=weights,
#    3227         cumulative=cumulative,
#    3228         bottom=bottom,
#    3229         histtype=histtype,
#    3230         align=align,
#    3231         orientation=orientation,
#    3232         rwidth=rwidth,
#    3233         log=log,
#    3234         color=color,
#    3235         label=label,
#    3236         stacked=stacked,
#    3237         **({"data": data} if data is not None else {}),
#    3238         **kwargs,
#    3239     )
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:7012, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7010 if patch:
#    7011     p = patch[0]
# -> 7012     p._internal_update(kwargs)
#    7013     if lbl is not None:
#    7014         p.set_label(lbl)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Polygon.set() got an unexpected keyword argument 'normed'

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 7
#       3 x3 = np.random.normal(3, 2, 1000)
#       5 kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)
# ----> 7 plt.hist(x1, **kwargs)
#       8 plt.hist(x2, **kwargs)
#       9 plt.hist(x3, **kwargs);
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3221, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3196 @_copy_docstring_and_deprecators(Axes.hist)
#    3197 def hist(
#    3198     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3219     BarContainer | Polygon | list[BarContainer | Polygon],
#    3220 ]:
# -> 3221     return gca().hist(
#    3222         x,
#    3223         bins=bins,
#    3224         range=range,
#    3225         density=density,
#    3226         weights=weights,
#    3227         cumulative=cumulative,
#    3228         bottom=bottom,
#    3229         histtype=histtype,
#    3230         align=align,
#    3231         orientation=orientation,
#    3232         rwidth=rwidth,
#    3233         log=log,
#    3234         color=color,
#    3235         label=label,
#    3236         stacked=stacked,
#    3237         **({"data": data} if data is not None else {}),
#    3238         **kwargs,
#    3239     )
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:7012, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7010 if patch:
#    7011     p = patch[0]
# -> 7012     p._internal_update(kwargs)
#    7013     if lbl is not None:
#    7014         p.set_label(lbl)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Polygon.set() got an unexpected keyword argument 'normed'

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 40 213 491 229  27]

# %% [markdown]
# #### Two-Dimensional Histograms and Binnings

# %%
mean = [0, 0]
cov = [[1, 1], [2, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\373805207.py:3: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %% [markdown]
# ##### plt.hist2d: Two-dimensional histogram

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('Counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %% [markdown]
# ##### plt.hexbin: Hexagonal binnings

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='Count in bin')

# %% [markdown]
# ##### Kernel density estimation

# %%
from scipy.stats import gaussian_kde

# fit an array of size [Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)

# Evaluate on a regular grid
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.revel(), Ygrid.revel()]))

# plot the result as an image
plt.imshow(Z.reshape(Xgrid, Ygrid),
            origin='lower', aspect='auto',
            extent=[-3.5, 3.5, -6, 6],
            cmap='Blues')
    
cb = plt.colorbar()
cb.set_label('density')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 11
#       9 ygrid = np.linspace(-6, 6, 40)
#      10 Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
# ---> 11 Z = kde.evaluate(np.vstack([Xgrid.revel(), Ygrid.revel()]))
#      13 # plot the result as an image
#      14 plt.imshow(Z.reshape(Xgrid, Ygrid),
#      15             origin='lower', aspect='auto',
#      16             extent=[-3.5, 3.5, -6, 6],
#      17             cmap='Blues')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'revel'

# %% [markdown]
# ## Customizing Plot Legends

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# %matplotlib inline

import numpy as np

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon= False)

fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)

fig

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# ### Choosing Elements for the legend

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))
lines = plt.plot(x, y)

# lines is a list of plt.Line2D instances
plt.legend(lines[:2], ['first', 'second']);

# %%
plt.plot(x, y[:, 0], label='first')
plt.plot(x, y[:, 1], label='second')
plt.plot(x, y[:, 2:])
plt.legend(framealpha=1, frameon=True);

# %% [markdown]
# ### Legend for Size of Plots

# %%
import pandas as pd

cities = pd.read_csv('data/california_cities.csv')

# Extracting the data we're intrested in
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c = np.log10(population), cmap='viridis',
            s = area, linewidth=0, alpha=0.5)


#plt.axis(aspect='equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Here we created the legend:
# we'll plot empty list with the desired set label

for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + 'km$^2$')

plt.legend(scatterpoints=1, frameon=False,
            labelspacing=1, title='City Area')

    
plt.title('California cities: Area and population');

# %% [markdown]
# ### Multiple Legends

# %%
fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)

for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
                    styles[i], color='black')

ax.axis('equal')

# Specify the lines and labels of the first legend
ax.legend(lines[:2], ['Line A', 'Line B'],
        loc='upper right', frameon=False)

#Create the second legend and add the artist manually
from matplotlib.legend import legend
leg = legend(ax, lines[2:], ['Line C', 'Line D'],
            loc='lower right', frameon=False)
ax.add_artist(leg);
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[66], line 18
#      14 ax.legend(lines[:2], ['Line A', 'Line B'],
#      15         loc='upper right', frameon=False)
#      17 #Create the second legend and add the artist manually
# ---> 18 from matplotlib.legend import legend
#      19 leg = legend(ax, lines[2:], ['Line C', 'Line D'],
#      20             loc='lower right', frameon=False)
#      21 ax.add_artist(leg);
#
# ImportError: cannot import name 'legend' from 'matplotlib.legend' (c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\legend.py)

# %% [markdown]
# ## Customizing Colorbars

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar();

# %% [markdown]
# #### Customizing Colorbars

# %%
plt.imshow(I, cmap='grey');

# %%
plt.cm?
# Out:
# Type:        module
# String form: <module 'matplotlib.cm' from 'c:\\Users\\Oxward\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\cm.py'>
# File:        c:\users\oxward\appdata\local\programs\python\python311\lib\site-packages\matplotlib\cm.py
# Docstring:
# Builtin colormaps, colormap handling utilities, and the `ScalarMappable` mixin.
#
# .. seealso::
#
#   :doc:`/gallery/color/colormap_reference` for a list of builtin colormaps.
#
#   :ref:`colormap-manipulation` for examples of how to make
#   colormaps.
#
#   :ref:`colormaps` an in-depth discussion of choosing
#   colormaps.
#
#   :ref:`colormapnorms` for more details about data normalization.

# %% [markdown]
# ##### Choosing the colormap

# %%
from matplotlib.colors import LinearSegmentedColormap

def grayscale_cmap(cmap):
    """Return a grayscale version of the given colormap"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))

    # convert RGBA to perceived grayscale luminace
    # cf. http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminace = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminace[:, np.newaxis]

    return LinearSegmentedColormap.from_list(cmap.name + "_gray", colors, cmap.N)

def view_colormap(cmap):
    """Plot a colormap with its grayscale equivalent"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))

    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    fig, ax = plt.subplots(2, figsize=(6, 2),
                            subplot_kw=dict(xticks=[], yticks=[]))
    ax[0].imshow([colors], extent=[0, 10, 0, 1])
    ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
view_colormap('jet')
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)

# %%
view_colormap('viridis')
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)

# %%
view_colormap('cubehelix')
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)

# %%
view_colormap('RdBu')
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\1135458741.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap)

# %% [markdown]
# ##### Color limits and extensions

# %%
# Make noise in 1% of the image pixels
speckles = (np.random.random(I.shape) < 0.01)
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))

plt.figure(figsize=(10, 3.5))

plt.subplot(1, 2, 1)
plt.imshow(I, cmap='RdBu')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(I, cmap='RdBu')
plt.colorbar(extend='both')
plt.clim(-1, 1);

# %% [markdown]
# ##### Discrete colorbars

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
plt.colorbar()
plt.clim(-1, 1);
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\2420005992.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))

# %% [markdown]
# ### Example: Handwritten Digits

# %%
# Load images of the digits = through 5 and visualize several of them

from sklearn.datasets import load_digits
digits = load_digits(n_class=6)

fit, ax = plt.subplots(8, 8, figsize=(6, 6))
for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xticks=[], yticks=[])

# %%
# project the digits into 2 dimensions using IsoMap

from sklearn.manifold import Isomap
iso = Isomap(n_components=2)
projection = iso.fit_transform(digits.data)
# Out:
# c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_isomap.py:383: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
# plot the results
plt.scatter(projection[:, 0], projection[:, 1], lw=0.1,
            c=digits.target, cmap=plt.cm.get_cmap('cubehelix', 6))
plt.colorbar(ticks=range(6), label='Digit value')
plt.clim(-0.5, 5.5)
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\870711155.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c=digits.target, cmap=plt.cm.get_cmap('cubehelix', 6))

# %% [markdown]
# ## Multiple Subplots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# ### plt.axes: Subplots by Hand

# %%
ax1 = plt.axes() # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                    xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                    ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# ### plt.subplot: Simple Grids of Subplots

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
            fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
            fontsize=18, ha='center')

# %% [markdown]
# ### plt.subplots: The whole Grid in One Go

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, index by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                        fontsize=18, ha='center')
            
fig

# %% [markdown]
# ### plt.GridSpec: More Complicated Arrangements

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

# %%
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]

x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()
y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# ## Text and Annotation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
#plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

# %% [markdown]
# ### Example: Effect of Holidays on US Births

# %%
births = pd.read_csv('data/births.csv')

quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 *  (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & ( births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year +
                            100 * births.month + 
                            births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births', 
                                    [births.index.month, births.index.day])
births_by_date.index = [pd.Timestamp(2012, month, day)
                        for (month, day) in births_by_date.index]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plots

style = dict(size= 10, color='gray')

ax.text('2012-1-1', 3950, 'New  Year\'s Day', **style)
ax.text('2012-7-4', 4250, 'Independence Day', ha='center', **style)
ax.text('2012-9-4', 4850, 'Labour Day', ha='center', **style)
ax.text('2012-10-31', 4600, 'Haloween', ha='right', **style)
ax.text('2012-11-25', 4450, 'Thanksgivine', ha='center', **style)
ax.text('2012-12-25', 3850, 'Christmas', ha='right', **style)

# Label the axes
ax.set(title= "USA births by day of the year (1969-1988)",
        ylabel= 'average daily births')

# Format the x axis with centerd month labeels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

# %% [markdown]
# ### Tranforms and Text Position

# %%
fig, ax = plt.subplots(facecolor='lightgray')
ax.axis([0, 10, 0, 10])

# transform=ax, transData is the default, but we'll specify it anyway
ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure);

# %%
ax.set_xlim(0, 2)
ax.set_ylim(-6, 6)
fig

# %% [markdown]
# ### Arrows and Annotation

# %%
# %matplotlib inline

fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('Local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('Local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle='->',
                            connectionstyle='angle3, angleA=0, angleB=-90'));

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mpl_dates
from matplotlib.patches import FancyArrowPatch

fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plot
ax.annotate("New Year's Day", xy=('2012-01-01', 4100), xycoords='data',
            xytext=(50, -30), textcoords='offset points',
            arrowprops=dict(arrowstyle='->',
                            connectionstyle='arc3, rad=-0.2'))

ax.annotate("Independence Day", xy=('2012-07-04', 4250), xycoords='data',
            bbox=dict(boxstyle="round", fc='none', ec='gray'),
            xytext=(10, -40), textcoords='offset points', ha='center',
            arrowprops=dict(arrowstyle='->'))

ax.annotate("Labour Day", xy=('2012-09-04', 4850), xycoords='data', ha='center',
            xytext=(0, -20), textcoords='offset points')

# Using FancyArrowPatch for double-headed arrow
arrow = FancyArrowPatch(('2012-09-01', 4850), ('2012-09-07', 4850),
                        arrowstyle='<->', mutation_scale=15, color='black')
ax.add_patch(arrow)

ax.annotate('Halloween', xy=('2012-10-31', 4600), xycoords='data',
            xytext=(-80, -40), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2012-11-25', 4500), xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=80,rad=20"))

ax.annotate('Christmas', xy=('2012-12-25', 3850), xycoords='data',
            xytext=(-30, 0), textcoords='offset points',
            size=13, ha='right', va="center",
            bbox=dict(boxstyle="round", alpha=0.1),
            arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1))

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
        ylabel='average daily births')
        
# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl_dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl_dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl_dates.DateFormatter('%h'))

ax.set_ylim(3600, 5400);

plt.show()

# %% [markdown]
# ## Customizing Ticks

# %% [markdown]
# ### Major and Minor Ticks

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
ax = plt.axes(xscale='log', yscale='log')

# %%
print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())
# Out:
# <matplotlib.ticker.LogLocator object at 0x000001D2929D3690>
# <matplotlib.ticker.LogLocator object at 0x000001D28A3CE990>

# %%
print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())
# Out:
# <matplotlib.ticker.LogFormatterSciNotation object at 0x000001D292AE9310>
# <matplotlib.ticker.LogFormatterSciNotation object at 0x000001D292A14550>

# %% [markdown]
# ### Hiding Ticks and labels

# %%
ax = plt.axes()
ax.plot(np.random.rand(50))

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(5, 5, figsize=(5, 5))
fig.subplots_adjust(hspace=0, wspace=0)

# Get some face data from scikit-learn
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces().images

for i in range(5):
    for j in range(5):
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        ax[i, j].imshow(faces[10 * i + j], cmap='bone')

# %% [markdown]
# ### Reducing or Increasing the Number of ticks

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %%
# For every axis, set the x and y major locator
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))
fig

# %% [markdown]
# ### Fancy Tick Formats

# %%
# Plot the sine and cosine curve

fig, ax = plt.subplots()

x = np.linspace(0, 3 * np.pi, 1000)
ax.plot(x, np.sin(x), lw=3, label='Sine')
ax.plot(x, np.cos(x), lw=3, label='Cosine')

# Set up grid, legend and limits
ax.grid(True)
ax.legend(frameon=False)
ax.axis('equal')
ax.set_xlim(0, 3 * np.pi);

# %%
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))
ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 4))

fig

# %%
def format_func(value, tick_number):
    # find the multiples of pi/2
    N = int(np.round(2 * value / np.pi))
    if N==0:
        return '0'
    elif N==1:
        return r"$\pi/2$"
    elif N==2:
        return r"$\pi$"
    elif N % 2 > 0:
        return r"${0}\pi/2$".format(N)
    else:
        return r"${0}\pi$".format(N // 2)

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
fig

# %% [markdown]
# ## Customizing Matplotlib: Configurations and Stylesheets

# %% [markdown]
# ### Customization by Hand

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.random.randn(1000)
plt.hist(x);

# %%
# Create figure and axis
fig, ax = plt.subplots()

# Use a gray background
ax.set_facecolor('#E6E6E6')
ax.set_axisbelow(True)

# Draw solid white grid lines
plt.grid(color='w', linestyle='solid')

# Hide axis spines
for spine in ax.spines.values():
    spine.set_visible(False)

# Hide top and right ticks
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# Lighten ticks and labels
ax.tick_params(colors='gray', direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('gray')
for tick in ax.get_yticklabels():
    tick.set_color('gray')

# Control the face and edge color of the histogram
ax.hist(x, edgecolor='#E6E6E6', color='#E6E6E6')
plt.show()

# %% [markdown]
# ### Changing the Defaults: rcParams

# %%
IPython_default = plt.rcParams.copy()

# %%
from matplotlib import cycler

colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
        axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
plt.hist(x);

# %%
for i in range(4):
    plt.plot(np.random.rand(10))

# %% [markdown]
# ### Stylesheets

# %%
plt.style.available[:5]
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh']

# %%
plt.style.use('_classic_test_patch')

# %%
with plt.style.context('_classic_test_patch'):
    for i in range(4):
        plt.plot(np.random.rand(10))

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %% [markdown]
# #### Default style

# %%
# reset rcParams
plt.rcParams.update(IPython_default);

# %%
hist_and_lines()

# %% [markdown]
# #### FiveThirtyEight style

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# #### ggplot

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# #### Bayesian Methods for Hackers style

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# #### Dark background

# %%
with plt.style.context('dark_background'):
    hist_and_lines()

# %% [markdown]
# #### Grayscale

# %%
with plt.style.context('grayscale'):
    hist_and_lines()

# %% [markdown]
# #### Seaborn style

# %%
import seaborn
hist_and_lines()

# %% [markdown]
# ## Three-Dimensional Plotting in Matplotlib

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.Figure()
ax = plt.axes(projection='3d')

# %% [markdown]
# ### Three-Dimensional Points and Lines

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for the three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, c=zdata, cmap='Greens');

# %% [markdown]
# ### Three-Dimensional Contour Plots

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmsp='binary')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z');
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_4476\321881007.py:3: UserWarning: The following kwargs were not used by contour: 'cmsp'
#   ax.contour3D(X, Y, Z, 50, cmsp='binary')
