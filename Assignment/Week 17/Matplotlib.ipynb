# %% [markdown]
# ## General Matplotlib Tips

# %% [markdown]
# ### Importiing matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting styles

# %%
plt.style.use('classic')

# %% [markdown]
# ### Show() or No show()? How to Display Your Plots

# %% [markdown]
# #### Ploting from a script

# %%
#------file: matplot.py-------

import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# #### Plotting from an IPython shell

# %%
# %matplotlib
#using matplotlib backend: TkAgg
# Out:
# Using matplotlib backend: TkAgg

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plotting from an IPython notebook

# %%
# %matplotlib inline

# %%
import numpy as np

x = np.linspace(0, 10, 100)

fig = plt.Figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# ### Saving figures to File

# %%
fig.savefig('my_figre.png')

# %%
# !ls -lh my_figre.png
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image
Image('my_figre.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ## Two Interfaces for the Price of One

# %%
plt.Figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# #### Object-oriented interface

# %%
# First create a grid of plots
# ax will be an array of two Axis objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ## Simple line plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ### Adjusting the Plot: Line Colors and styles

# %%
plt.plot(x, np.sin(x - 0), color= 'blue') # specify color by name
plt.plot(x, np.sin(x - 1), color= 'g')    # specify color by code(rgbcmyk)
plt.plot(x, np.sin(x - 2), color= '0.75') # greyscale between 0 and 1
plt.plot(x, np.sin(x - 3), color= '#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color= (1.0, 0.2, 0.3)) #RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color= 'chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle= 'solid')
plt.plot(x, x + 1, linestyle= 'dashed')
plt.plot(x, x + 2, linestyle= 'dashdot')
plt.plot(x, x + 3, linestyle= 'dotted')

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle = '-') # solid
plt.plot(x, x + 5, linestyle = '--') # dashed
plt.plot(x, x + 6, linestyle = '-.') # dashdot
plt.plot(x, x + 7, linestyle = ':') # dotted

# %%
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r') # dotted red

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
# Out:
# Text(0.5, 1.0, 'A Sine Curve')

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('X')
plt.ylabel('Sin(X)');

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')

plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
        xlabel='x', ylabel='sin(x)',
        title='A simple plot');

# %% [markdown]
# ## Simple Scatter plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ### Scatter plots with plt.plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
            label="marker= '{0}'".format(marker))
        
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-ok'); # line(-), circle marker (o), black(k)

# %%
plt.plot(x, y, '-p', color='gray',
        markersize=15, linewidth=4,
        markerfacecolor='white',
        markeredgecolor='gray',
        markeredgewidth=2)

plt.ylim(-1.2, 1.2);

# %% [markdown]
# ### Scatter plots with plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')

plt.colorbar(); # show the color scale

# %%
from sklearn.datasets import load_iris

iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s = 100 * features[3], c = iris.target, cmap= 'viridis')
        
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# ### plot Versus scatter: A Note on Efficiency

# %% [markdown]
# ## Visualizing Errors

# %% [markdown]
# #### Basic Errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
            ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# #### Continuous Error

# %%
from sklearn.gaussian_process import GaussianProcessRegressor, GaussianProcessClassifier

# %%
# define the model and draw some data

model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# compute the Gaussian Process fit
gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
                                random_state= 100)
                    
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10,  1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE= True)
dyfit = 2 * np.sqrt(MSE) # 2*sigma ~ 95% confidence region
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 8
#       5 ydata = model(xdata)
#       7 # compute the Gaussian Process fit
# ----> 8 gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
#       9                                 random_state= 100)
#      11 gp.fit(xdata[:, np.newaxis], ydata)
#      13 xfit = np.linspace(0, 10,  1000)
#
# NameError: name 'GaussianProcess' is not defined

# %% [markdown]
# ## Density and Color plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Visualizing a Three-Dimensional Function

# %%
def f(x, y):
    np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 plt.contour(X, Y, Z, colors='black');
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2924, in contour(data, *args, **kwargs)
#    2922 @_copy_docstring_and_deprecators(Axes.contour)
#    2923 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2924     __ret = gca().contour(
#    2925         *args, **({"data": data} if data is not None else {}), **kwargs
#    2926     )
#    2927     if __ret._A is not None:  # type: ignore[attr-defined]
#    2928         sci(__ret)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:6517, in Axes.contour(self, *args, **kwargs)
#    6508 """
#    6509 Plot contour lines.
#    6510
#    (...)
#    6514 %(contour_doc)s
#    6515 """
#    6516 kwargs['filled'] = False
# -> 6517 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6518 self._request_autoscale_view()
#    6519 return contours
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D
