# %%
import pandas as pd
import numpy as np

# %%
X = [[3, 5], [4, 6], [5, 12]]

data = pd.DataFrame(X)

data
# Out:
#    0   1
# 0  3   5
# 1  4   6
# 2  5  12

# %%
X = [[3, 5], [4, 6], [5, 12]]

data = pd.DataFrame(X, columns=['group_a', 'group_b'])

data
# Out:
#    group_a  group_b
# 0        3        5
# 1        4        6
# 2        5       12

# %%
data.iloc(0)

# %%
data.loc(0)

# %%
data.iloc[0]
# Out:
# group_a    3
# group_b    5
# Name: 0, dtype: int64

# %%
data.iloc[1]
# Out:
# group_a    4
# group_b    6
# Name: 1, dtype: int64

# %%
data['group_a']
# Out:
# 0    3
# 1    4
# 2    5
# Name: group_a, dtype: int64

# %%
data['group_b']
# Out:
# 0     5
# 1     6
# 2    12
# Name: group_b, dtype: int64

# %%
data['group_c'] = [12, -12, 8]

# %%
data
# Out:
#    group_a  group_b  group_c
# 0        3        5       12
# 1        4        6      -12
# 2        5       12        8

# %%
data['group_d'] = data['group_a'] + data['group_b']

data
# Out:
#    group_a  group_b  group_c  group_d
# 0        3        5       12        8
# 1        4        6      -12       10
# 2        5       12        8       17

# %%
data['group_d'].sum()
# Out:
# 35

# %%
data['group_d%'] = data['group_d']/data['group_d'].sum()*100
data
# Out:
#    group_a  group_b  group_c  group_d   group_d%
# 0        3        5       12        8  22.857143
# 1        4        6      -12       10  28.571429
# 2        5       12        8       17  48.571429

# %%
data.info
# Out:
# <bound method DataFrame.info of    group_a  group_b  group_c  group_d   group_d%
# 0        3        5       12        8  22.857143
# 1        4        6      -12       10  28.571429
# 2        5       12        8       17  48.571429>

# %%
data.describe()
# Out:
#        group_a    group_b    group_c    group_d   group_d%
# count      3.0   3.000000   3.000000   3.000000   3.000000
# mean       4.0   7.666667   2.666667  11.666667  33.333333
# std        1.0   3.785939  12.858201   4.725816  13.502330
# min        3.0   5.000000 -12.000000   8.000000  22.857143
# 25%        3.5   5.500000  -2.000000   9.000000  25.714286
# 50%        4.0   6.000000   8.000000  10.000000  28.571429
# 75%        4.5   9.000000  10.000000  13.500000  38.571429
# max        5.0  12.000000  12.000000  17.000000  48.571429

# %%
np.sum(data['group_d%'])
# Out:
# 100.0

# %%
data.sum()
# Out:
# group_a      12.0
# group_b      23.0
# group_c       8.0
# group_d      35.0
# group_d%    100.0
# dtype: float64

# %%
y = np.random.randint(12, 100, (50, 5))

# %%
data1 = pd.DataFrame(y, columns=list('abcde'))
data1
# Out:
#      a   b   c   d   e
# 0   55  26  94  47  16
# 1   37  96  92  92  72
# 2   22  99  44  57  96
# 3   17  75  76  85  67
# 4   54  46  41  88  39
# 5   13  88  44  34  23
# 6   23  40  55  55  78
# 7   58  70  77  33  40
# 8   34  18  85  43  32
# 9   22  16  94  14  95
# 10  43  12  53  76  19
# 11  40  78  45  12  46
# 12  13  83  59  49  15
# 13  14  34  15  39  98
# 14  23  77  61  44  98
# 15  75  38  44  64  36
# 16  21  39  12  38  65
# 17  53  66  25  35  79
# 18  40  19  93  25  36
# 19  85  29  54  89  16
# 20  88  85  32  89  94
# 21  32  93  68  73  61
# 22  93  25  57  23  74
# 23  25  81  34  87  39
# 24  34  70  72  32  88
# 25  96  53  72  24  73
# 26  67  81  39  59  77
# 27  70  87  72  25  42
# 28  21  98  70  76  76
# 29  84  95  47  56  80
# 30  50  71  39  67  14
# 31  54  29  53  62  56
# 32  36  92  60  78  79
# 33  14  75  72  96  90
# 34  83  65  83  34  27
# 35  18  91  71  42  26
# 36  93  68  86  57  25
# 37  61  24  92  32  38
# 38  85  75  21  38  19
# ...

# %%
data1.head()
# Out:
#     a   b   c   d   e
# 0  55  26  94  47  16
# 1  37  96  92  92  72
# 2  22  99  44  57  96
# 3  17  75  76  85  67
# 4  54  46  41  88  39

# %%
data1.tail()
# Out:
#      a   b   c   d   e
# 45  45  32  73  70  58
# 46  53  92  73  54  52
# 47  62  70  89  95  70
# 48  86  21  64  18  67
# 49  94  76  85  81  48

# %%
data1.sample() #randomly pick a row
# Out:
#     a   b   c   d   e
# 4  54  46  41  88  39

# %%
data1.sample(3)
# Out:
#      a   b   c   d   e
# 44  46  24  50  94  42
# 31  54  29  53  62  56
# 28  21  98  70  76  76

# %%
data
# Out:
#    group_a  group_b  group_c  group_d   group_d%
# 0        3        5       12        8  22.857143
# 1        4        6      -12       10  28.571429
# 2        5       12        8       17  48.571429

# %%
data.drop?
# Out:
# Signature:
# data.drop(
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise',
# ) -> 'DataFrame | None'
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by directly specifying index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the :ref:`user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as a list-like.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
# ...

# %%
data.drop(labels=[0])
# Out:
#    group_a  group_b  group_c  group_d   group_d%
# 1        4        6      -12       10  28.571429
# 2        5       12        8       17  48.571429

# %%
data.drop(labels=['group_d%'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.drop(labels=['group_d%'])
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
data.drop(labels=['group_d%'],axis=1)
# Out:
#    group_a  group_b  group_c  group_d
# 0        3        5       12        8
# 1        4        6      -12       10
# 2        5       12        8       17

# %%
data
# Out:
#    group_a  group_b  group_c  group_d   group_d%
# 0        3        5       12        8  22.857143
# 1        4        6      -12       10  28.571429
# 2        5       12        8       17  48.571429

# %%
data2 = data.drop(labels=['group_d%'],axis=1)
data2
# Out:
#    group_a  group_b  group_c  group_d
# 0        3        5       12        8
# 1        4        6      -12       10
# 2        5       12        8       17

# %%
data.drop(labels=['group_d%'],axis=1, inplace=True)

# %%
data
# Out:
#    group_a  group_b  group_c  group_d
# 0        3        5       12        8
# 1        4        6      -12       10
# 2        5       12        8       17

# %% [markdown]
# # Working with external data

# %%
import pandas as pd
import numpy as np

# %%
country_data = pd.read_csv('data/Country-data.csv') # we can also use ('./Country-data.csv') to 
# search for the file in thesame path and also use ('../Country-data.csv') to go to the parent folder 
# in my system, we can also use ('../../Country-data.csv') to go further.

country_data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
len(country_data.columns)
# Out:
# 10

# %%
len(country_data.index)
# Out:
# 167

# %%
country_data.tail()
# Out:
#        country  child_mort  exports  health  imports  income  inflation  \
# 162    Vanuatu        29.2     46.6    5.25     52.7    2950       2.62
# 163  Venezuela        17.1     28.5    4.91     17.6   16500      45.90
# 164    Vietnam        23.3     72.0    6.84     80.2    4490      12.10
# 165      Yemen        56.3     30.0    5.18     34.4    4480      23.60
# 166     Zambia        83.1     37.0    5.89     30.9    3280      14.00
#
#      life_expec  total_fer   gdpp
# 162        63.0       3.50   2970
# 163        75.4       2.47  13500
# 164        73.1       1.95   1310
# 165        67.5       4.67   1310
# 166        52.0       5.40   1460

# %%
country_data.tail(9)
# Out:
#             country  child_mort  exports  health  imports  income  inflation  \
# 158  United Kingdom         5.2     28.2    9.64     30.8   36200       1.57
# 159   United States         7.3     12.4   17.90     15.8   49400       1.22
# 160         Uruguay        10.6     26.3    8.35     25.4   17100       4.91
# 161      Uzbekistan        36.3     31.7    5.81     28.5    4240      16.50
# 162         Vanuatu        29.2     46.6    5.25     52.7    2950       2.62
# 163       Venezuela        17.1     28.5    4.91     17.6   16500      45.90
# 164         Vietnam        23.3     72.0    6.84     80.2    4490      12.10
# 165           Yemen        56.3     30.0    5.18     34.4    4480      23.60
# 166          Zambia        83.1     37.0    5.89     30.9    3280      14.00
#
#      life_expec  total_fer   gdpp
# 158        80.3       1.92  38900
# 159        78.7       1.93  48400
# 160        76.4       2.08  11900
# 161        68.8       2.34   1380
# ...

# %%
country_data.sample()
# Out:
#     country  child_mort  exports  health  imports  income  inflation  \
# 53  Finland         3.0     38.7    8.95     37.4   39800      0.351
#
#     life_expec  total_fer   gdpp
# 53        80.0       1.87  46200

# %%
country_data.sample(5)
# Out:
#         country  child_mort  exports  health  imports  income  inflation  \
# 39   Costa Rica        10.2    33.20   10.90     35.0   13000      6.570
# 133   Singapore         2.8   200.00    3.96    174.0   72100     -0.046
# 26      Burundi        93.6     8.92   11.60     39.2     764     12.300
# 121      Poland         6.0    40.10    7.46     42.1   21800      1.660
# 82       Kuwait        10.8    66.70    2.63     30.4   75200     11.200
#
#      life_expec  total_fer   gdpp
# 39         80.4       1.92   8200
# 133        82.7       1.15  46600
# 26         57.7       6.26    231
# 121        76.3       1.41  12600
# 82         78.2       2.21  38500

# %%
country_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
country_data.shape
# Out:
# (167, 10)

# %%
country_data.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
country_data.describe?
# Out:
# Signature: country_data.describe(percentiles=None, include=None, exclude=None) -> 'Self'
# Docstring:
# Generate descriptive statistics.
#
# Descriptive statistics include those that summarize the central
# tendency, dispersion and shape of a
# dataset's distribution, excluding ``NaN`` values.
#
# Analyzes both numeric and object series, as well
# as ``DataFrame`` column sets of mixed data types. The output
# will vary depending on what is provided. Refer to the notes
# below for more detail.
#
# Parameters
# ----------
# percentiles : list-like of numbers, optional
#     The percentiles to include in the output. All should
#     fall between 0 and 1. The default is
#     ``[.25, .5, .75]``, which returns the 25th, 50th, and
#     75th percentiles.
# include : 'all', list-like of dtypes or None (default), optional
#     A white list of data types to include in the result. Ignored
#     for ``Series``. Here are the options:
#
# ...

# %%
country_data.describe(include=[int])
# Out:
#               income           gdpp
# count     167.000000     167.000000
# mean    17144.688623   12964.155689
# std     19278.067698   18328.704809
# min       609.000000     231.000000
# 25%      3355.000000    1330.000000
# 50%      9960.000000    4660.000000
# 75%     22800.000000   14050.000000
# max    125000.000000  105000.000000

# %%
country_data.describe(include=[float])
# Out:
#        child_mort     exports      health     imports   inflation  life_expec  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean    38.270060   41.108976    6.815689   46.890215    7.781832   70.555689
# std     40.328931   27.412010    2.746837   24.209589   10.570704    8.893172
# min      2.600000    0.109000    1.810000    0.065900   -4.210000   32.100000
# 25%      8.250000   23.800000    4.920000   30.200000    1.810000   65.300000
# 50%     19.300000   35.000000    6.320000   43.300000    5.390000   73.100000
# 75%     62.100000   51.350000    8.600000   58.750000   10.750000   76.800000
# max    208.000000  200.000000   17.900000  174.000000  104.000000   82.800000
#
#         total_fer
# count  167.000000
# mean     2.947964
# std      1.513848
# min      1.150000
# 25%      1.795000
# 50%      2.410000
# 75%      3.880000
# max      7.490000

# %%
country_data.describe(include=[object])
# Out:
#             country
# count           167
# unique          167
# top     Afghanistan
# freq              1

# %%
country_data.describe(include=[int, object, float])
# Out:
#             country  child_mort     exports      health     imports  \
# count           167  167.000000  167.000000  167.000000  167.000000
# unique          167         NaN         NaN         NaN         NaN
# top     Afghanistan         NaN         NaN         NaN         NaN
# freq              1         NaN         NaN         NaN         NaN
# mean            NaN   38.270060   41.108976    6.815689   46.890215
# std             NaN   40.328931   27.412010    2.746837   24.209589
# min             NaN    2.600000    0.109000    1.810000    0.065900
# 25%             NaN    8.250000   23.800000    4.920000   30.200000
# 50%             NaN   19.300000   35.000000    6.320000   43.300000
# 75%             NaN   62.100000   51.350000    8.600000   58.750000
# max             NaN  208.000000  200.000000   17.900000  174.000000
#
#                income   inflation  life_expec   total_fer           gdpp
# count      167.000000  167.000000  167.000000  167.000000     167.000000
# ...

# %%
country_data.describe(include=[int, object])
# Out:
#             country         income           gdpp
# count           167     167.000000     167.000000
# unique          167            NaN            NaN
# top     Afghanistan            NaN            NaN
# freq              1            NaN            NaN
# mean            NaN   17144.688623   12964.155689
# std             NaN   19278.067698   18328.704809
# min             NaN     609.000000     231.000000
# 25%             NaN    3355.000000    1330.000000
# 50%             NaN    9960.000000    4660.000000
# 75%             NaN   22800.000000   14050.000000
# max             NaN  125000.000000  105000.000000

# %%
# Assignment
# 1. How to use describe to remove a particular column

# %%
import pandas as pd

# %%
data = pd.read_csv('data_set/drinks.csv')

data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
data.set_index('country').head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
data.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
data.set_index('country').shape
# Out:
# (193, 5)

# %%
data.shape
# Out:
# (193, 6)

# %%
data.head
# Out:
# <bound method NDFrame.head of          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# ...

# %%
# data.set_index('country', inplace=True)

data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
data1 = data.set_index('country')

# %%
data1.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
data2 = data.set_index('continent')

# %%
data2.head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# EU                                  4.9
# AF                                  0.7
# EU                                 12.4
# AF                                  5.9

# %%
data.sort_values('country')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
data.sort_values('continent')
# Out:
#                           country  beer_servings  spirit_servings  \
# 192                      Zimbabwe             64               18
# 152                    Seychelles            157               25
# 150                       Senegal              9                1
# 95                        Lesotho             82               29
# 142                        Rwanda             43                2
# ..                            ...            ...              ...
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 192              4                           4.7        AF
# ...

# %%
data.sort_values('continent').head(20)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 192           Zimbabwe             64               18              4
# 152         Seychelles            157               25             51
# 150            Senegal              9                1              7
# 95             Lesotho             82               29              0
# 142             Rwanda             43                2              0
# 47            DR Congo             32                3              1
# 49            Djibouti             15               44              3
# 53               Egypt              6                4              1
# 55   Equatorial Guinea             92                0            233
# 56             Eritrea             18                0              0
# 58            Ethiopia             20                3              0
# 62               Gabon            347               98             59
# ...

# %%
data.sort_values('continent', ascending=False)
# Out:
#                           country  beer_servings  spirit_servings  \
# 52                        Ecuador            162               74
# 72                         Guyana             93              302
# 23                         Brazil            245              145
# 188                     Venezuela            333              100
# 20                        Bolivia            167               41
# ..                            ...            ...              ...
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 52               3                           4.2        SA
# ...

# %%
data.sort_values('continent', ascending=False).head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 52            Ecuador            162               74              3
# 72             Guyana             93              302              1
# 23             Brazil            245              145             16
# 188         Venezuela            333              100              3
# 20            Bolivia            167               41              8
# 35              Chile            130              124            172
# 133              Peru            163              160             21
# 37           Colombia            159               76              3
# 132          Paraguay            213              117             74
# 185           Uruguay            115               35            220
# 6           Argentina            193               25            221
# 163          Suriname            128              178              7
# 187           Vanuatu             21               18             11
# ...

# %%
data.sort_values('beer_servings', ascending=False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# ..              ...            ...              ...            ...
# 107      Mauritania              0                0              0
# 158         Somalia              0                0              0
# 111          Monaco              0                0              0
# 128        Pakistan              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# ...

# %%
data2 = data.set_index(['continent', 'country'])

# %%
data2.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data3 = data.set_index(['continent', 'country'])

data3.sort_index()
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %%
data.continent.unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
len(data.continent.unique())
# Out:
# 6

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\354339855.py in ?()
# ----> 1 data.unique()
#
# c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
## the country and continent with the largest and least consumption of alcohol or drink but there should be 
# no (0) value

# %%
import numpy as np
import pandas as pd

# %%
np.nan * 2
# Out:
# nan

# %%
np.nan + 2
# Out:
# nan

# %%
data = pd.read_csv('data_set/drinks.csv')
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
data.continent.unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
data.sort_values('continent')
# Out:
#                           country  beer_servings  spirit_servings  \
# 192                      Zimbabwe             64               18
# 152                    Seychelles            157               25
# 150                       Senegal              9                1
# 95                        Lesotho             82               29
# 142                        Rwanda             43                2
# ..                            ...            ...              ...
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 192              4                           4.7        AF
# ...

# %%
data.continent.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
data.continent.isna().sort_values()
# Out:
# 0      False
# 118    False
# 119    False
# 120    False
# 121    False
#        ...
# 69      True
# 68      True
# 122     True
# 43      True
# 51      True
# Name: continent, Length: 193, dtype: bool

# %%
data.continent.isna().sum()
# Out:
# 23

# %%
data.dropna()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
data.shape
# Out:
# (193, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
data1 = data.dropna()

# %%
data1.continent.unique()
# Out:
# array(['AS', 'EU', 'AF', 'SA', 'OC'], dtype=object)

# %%
23/193
# Out:
# 0.11917098445595854

# %%
data.dropna?
# Out:
# Signature:
# data.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
# ...

# %%
data.dropna(axis=1)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
data.loc[data['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
data.loc[data['continent'].isnull()].shape
# Out:
# (23, 6)

# %%
data.loc[data['continent'].isna()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
data.loc[data['continent'].isna()].shape
# Out:
# (23, 6)

# %% [markdown]
# ## Titanic Dataset

# %%
titanic = pd.read_csv('data_set/titanic/train.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic1 = titanic.dropna()

# %%
titanic1.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
titanic1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
(891-183)/891
# Out:
# 0.7946127946127947

# %%
titanic.dropna?
# Out:
# Signature:
# titanic.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
# ...

# %%
titanic.dropna(subset=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## fill by a value
## forward and bakword
## interpolation
## personal research

# %%
titanic[titanic.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic2 = titanic

# %%
titanic2.Embarked.fillna(value='C', inplace=True)

# %%
titanic2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic2.iloc[61, :]
# Out:
# PassengerId                     62
# Survived                         1
# Pclass                           1
# Name           Icard, Miss. Amelie
# Sex                         female
# Age                           38.0
# SibSp                            0
# Parch                            0
# Ticket                      113572
# Fare                          80.0
# Cabin                          B28
# Embarked                         C
# Name: 61, dtype: object

# %%
titanic2.iloc[[61, 829], :] # fancy indexing
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28        C
# 829  female  62.0      0      0  113572  80.0   B28        C

# %%
# Look into forward and backword fill

# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv('data_set/titanic/train.csv')

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.Age.fillna?
# Out:
# Signature:
# titanic.Age.fillna(
#     value: 'Hashable | Mapping | Series | DataFrame | None' = None,
#     *,
#     method: 'FillnaOptions | None' = None,
#     axis: 'Axis | None' = None,
#     inplace: 'bool_t' = False,
#     limit: 'int | None' = None,
#     downcast: 'dict | None | lib.NoDefault' = <no_default>,
# ) -> 'Self | None'
# Docstring:
# Fill NA/NaN values using the specified method.
#
# Parameters
# ----------
# value : scalar, dict, Series, or DataFrame
#     Value to use to fill holes (e.g. 0), alternately a
#     dict/Series/DataFrame of values specifying which value to use for
#     each index (for a Series) or column (for a DataFrame).  Values not
#     in the dict/Series/DataFrame will not be filled. This value cannot
#     be a list.
# method : {'backfill', 'bfill', 'ffill', None}, default None
#     Method to use for filling holes in reindexed Series:
#
#     * ffill: propagate last valid observation forward to next valid.
# ...

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.iloc[16]
# Out:
# PassengerId                      17
# Survived                          0
# Pclass                            3
# Name           Rice, Master. Eugene
# Sex                            male
# Age                             2.0
# SibSp                             4
# Parch                             1
# Ticket                       382652
# Fare                         29.125
# Cabin                           NaN
# Embarked                          Q
# Name: 16, dtype: object

# %%
titanic.Age.fillna(method='ffill').head(7)
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_10972\3645132376.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic.Age.fillna(method='ffill').head(7)
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    35.0
# 6    54.0
# Name: Age, dtype: float64

# %%
titanic.Age.fillna(method='ffill').iloc[[16, 17]]
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_10972\2643525649.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic.Age.fillna(method='ffill').iloc[[16, 17]]
# 16    2.0
# 17    2.0
# Name: Age, dtype: float64

# %%
titanic1 = titanic

# %%
titanic1.Age.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Oxward\AppData\Local\Temp\ipykernel_10972\223750001.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic1.Age.fillna(method='ffill', inplace=True)

# %%
titanic1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.Age.mean()
# Out:
# 29.581560044893376

# %%
titanic.Age.mode()[0]
# Out:
# 24.0

# %%
titanic.Age.median()
# Out:
# 28.0

# %%
titanic.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
titanic.Age.fillna(value=titanic.Age.mean())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.Embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic.Age.std()
# Out:
# 14.554589813600968

# %%
# Interpolation

# %% [markdown]
# ### Date Transformation

# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv('data_set/titanic/train.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Name.split(',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10040\1016850830.py in ?()
# ----> 1 titanic.Name.split(',')
#
# c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
titanic.Name.str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic.Name.str.split(',').values
# Out:
# array([list(['Braund', ' Mr. Owen Harris']),
#        list(['Cumings', ' Mrs. John Bradley (Florence Briggs Thayer)']),
#        list(['Heikkinen', ' Miss. Laina']),
#        list(['Futrelle', ' Mrs. Jacques Heath (Lily May Peel)']),
#        list(['Allen', ' Mr. William Henry']),
#        list(['Moran', ' Mr. James']),
#        list(['McCarthy', ' Mr. Timothy J']),
#        list(['Palsson', ' Master. Gosta Leonard']),
#        list(['Johnson', ' Mrs. Oscar W (Elisabeth Vilhelmina Berg)']),
#        list(['Nasser', ' Mrs. Nicholas (Adele Achem)']),
#        list(['Sandstrom', ' Miss. Marguerite Rut']),
#        list(['Bonnell', ' Miss. Elizabeth']),
#        list(['Saundercock', ' Mr. William Henry']),
#        list(['Andersson', ' Mr. Anders Johan']),
#        list(['Vestrom', ' Miss. Hulda Amanda Adolfina']),
#        list(['Hewlett', ' Mrs. (Mary D Kingcome) ']),
#        list(['Rice', ' Master. Eugene']),
#        list(['Williams', ' Mr. Charles Eugene']),
# ...

# %%
data = titanic.Name.str.split(',').values

# %%
data.shape
# Out:
# (891,)

# %%
data[0]
# Out:
# ['Braund', ' Mr. Owen Harris']

# %%
data[0][0]
# Out:
# 'Braund'

# %%
data[0][1]
# Out:
# ' Mr. Owen Harris'

# %%
surnames = []
other_names = []

# %%
for name in data:
    print(name)
# Out:
# ['Braund', ' Mr. Owen Harris']
# ['Cumings', ' Mrs. John Bradley (Florence Briggs Thayer)']
# ['Heikkinen', ' Miss. Laina']
# ['Futrelle', ' Mrs. Jacques Heath (Lily May Peel)']
# ['Allen', ' Mr. William Henry']
# ['Moran', ' Mr. James']
# ['McCarthy', ' Mr. Timothy J']
# ['Palsson', ' Master. Gosta Leonard']
# ['Johnson', ' Mrs. Oscar W (Elisabeth Vilhelmina Berg)']
# ['Nasser', ' Mrs. Nicholas (Adele Achem)']
# ['Sandstrom', ' Miss. Marguerite Rut']
# ['Bonnell', ' Miss. Elizabeth']
# ['Saundercock', ' Mr. William Henry']
# ['Andersson', ' Mr. Anders Johan']
# ['Vestrom', ' Miss. Hulda Amanda Adolfina']
# ['Hewlett', ' Mrs. (Mary D Kingcome) ']
# ['Rice', ' Master. Eugene']
# ['Williams', ' Mr. Charles Eugene']
# ['Vander Planke', ' Mrs. Julius (Emelia Maria Vandemoortele)']
# ['Masselmani', ' Mrs. Fatima']
# ['Fynney', ' Mr. Joseph J']
# ['Beesley', ' Mr. Lawrence']
# ['McGowan', ' Miss. Anna "Annie"']
# ['Sloper', ' Mr. William Thompson']
# ['Palsson', ' Miss. Torborg Danira']
# ...

# %%
# assignment(remove the title)

# %%
for name in data:
    surnames.append(name[0])
    other_names.append(name[1].strip())

# %%
surnames
# Out:
# ['Braund',
#  'Cumings',
#  'Heikkinen',
#  'Futrelle',
#  'Allen',
#  'Moran',
#  'McCarthy',
#  'Palsson',
#  'Johnson',
#  'Nasser',
#  'Sandstrom',
#  'Bonnell',
#  'Saundercock',
#  'Andersson',
#  'Vestrom',
#  'Hewlett',
#  'Rice',
#  'Williams',
#  'Vander Planke',
#  'Masselmani',
#  'Fynney',
#  'Beesley',
#  'McGowan',
#  'Sloper',
#  'Palsson',
#  'Asplund',
#  'Emir',
#  'Fortune',
#  "O'Dwyer",
#  'Todoroff',
#  'Uruchurtu',
#  'Spencer',
#  'Glynn',
#  'Wheadon',
#  'Meyer',
#  'Holverson',
#  'Mamee',
#  'Cann',
#  'Vander Planke',
#  'Nicola-Yarred',
#  'Ahlin',
#  'Turpin',
#  'Kraeff',
#  'Laroche',
#  'Devaney',
#  'Rogers',
#  'Lennon',
#  "O'Driscoll",
#  'Samaan',
#  'Arnold-Franchi',
#  'Panula',
#  'Nosworthy',
#  'Harper',
#  'Faunthorpe',
#  'Ostby',
#  'Woolner',
#  'Rugg',
#  'Novel',
#  'West',
#  'Goodwin',
#  'Sirayanian',
#  'Icard',
#  'Harris',
#  'Skoog',
#  'Stewart',
#  'Moubarek',
#  'Nye',
#  'Crease',
#  'Andersson',
#  'Kink',
#  'Jenkin',
# ...

# %%
other_names
# Out:
# ['Mr. Owen Harris',
#  'Mrs. John Bradley (Florence Briggs Thayer)',
#  'Miss. Laina',
#  'Mrs. Jacques Heath (Lily May Peel)',
#  'Mr. William Henry',
#  'Mr. James',
#  'Mr. Timothy J',
#  'Master. Gosta Leonard',
#  'Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Mrs. Nicholas (Adele Achem)',
#  'Miss. Marguerite Rut',
#  'Miss. Elizabeth',
#  'Mr. William Henry',
#  'Mr. Anders Johan',
#  'Miss. Hulda Amanda Adolfina',
#  'Mrs. (Mary D Kingcome)',
#  'Master. Eugene',
#  'Mr. Charles Eugene',
#  'Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Mrs. Fatima',
#  'Mr. Joseph J',
#  'Mr. Lawrence',
#  'Miss. Anna "Annie"',
#  'Mr. William Thompson',
#  'Miss. Torborg Danira',
#  'Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Mr. Farred Chehab',
#  'Mr. Charles Alexander',
#  'Miss. Ellen "Nellie"',
#  'Mr. Lalio',
#  'Don. Manuel E',
#  'Mrs. William Augustus (Marie Eugenie)',
#  'Miss. Mary Agatha',
#  'Mr. Edward H',
#  'Mr. Edgar Joseph',
#  'Mr. Alexander Oskar',
# ...

# %%
titanic['Surname'] = surnames

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic['Other Names'] = other_names

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic.drop('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 titanic.drop('Name')
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %%
titanic.drop('Name', axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 titanic.drop('Name', axis=1).head()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    Surname  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                   Other Names
# 0                             Mr. Owen Harris
# 1  Mrs. John Bradley (Florence Briggs Thayer)
# 2                                 Miss. Laina
# 3          Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
titanic.drop('Name', axis=1, inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    Surname  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                   Other Names
# 0                             Mr. Owen Harris
# 1  Mrs. John Bradley (Florence Briggs Thayer)
# 2                                 Miss. Laina
# 3          Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Surname          0
# Other Names      0
# dtype: int64

# %%
# map
# apply
# apply_map

# %%
titanic.apply?
# Out:
# Signature:
# titanic.apply(
#     func: 'AggFuncType',
#     axis: 'Axis' = 0,
#     raw: 'bool' = False,
#     result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None,
#     args=(),
#     by_row: "Literal[False, 'compat']" = 'compat',
#     **kwargs,
# )
# Docstring:
# Apply a function along an axis of the DataFrame.
#
# Objects passed to the function are Series objects whose index is
# either the DataFrame's index (``axis=0``) or the DataFrame's columns
# (``axis=1``). By default (``result_type=None``), the final return type
# is inferred from the return type of the applied function. Otherwise,
# it depends on the `result_type` argument.
#
# Parameters
# ----------
# func : function
#     Function to apply to each column or row.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Axis along which the function is applied:
#
#     * 0 or 'index': apply function to each column.
#     * 1 or 'columns': apply function to each row.
#
# raw : bool, default False
# ...

# %%
titanic.map?
# Out:
# Signature:
# titanic.map(
#     func: 'PythonFuncType',
#     na_action: 'str | None' = None,
#     **kwargs,
# ) -> 'DataFrame'
# Docstring:
# Apply a function to a Dataframe elementwise.
#
# .. versionadded:: 2.1.0
#
#    DataFrame.applymap was deprecated and renamed to DataFrame.map.
#
# This method applies a function that accepts and returns a scalar
# to every element of a DataFrame.
#
# Parameters
# ----------
# func : callable
#     Python function, returns a single value from a single value.
# na_action : {None, 'ignore'}, default None
#     If 'ignore', propagate NaN values, without passing them to func.
# **kwargs
#     Additional keyword arguments to pass as keywords arguments to
#     `func`.
#
# Returns
# -------
# DataFrame
#     Transformed DataFrame.
#
# See Also
# --------
# DataFrame.apply : Apply a function along input axis of DataFrame.
# DataFrame.replace: Replace values given in `to_replace` with `value`.
# Series.map : Apply a function elementwise on a Series.
# ...

# %%
titanic.Fare.apply(int)
# Out:
# 0       7
# 1      71
# 2       7
# 3      53
# 4       8
#        ..
# 886    13
# 887    30
# 888    23
# 889    30
# 890     7
# Name: Fare, Length: 891, dtype: int64

# %%
titanic.Fare.apply(round)
# Out:
# 0       7
# 1      71
# 2       8
# 3      53
# 4       8
#        ..
# 886    13
# 887    30
# 888    23
# 889    30
# 890     8
# Name: Fare, Length: 891, dtype: int64

# %%
titanic.Fare.apply(str)
# Out:
# 0         7.25
# 1      71.2833
# 2        7.925
# 3         53.1
# 4         8.05
#         ...
# 886       13.0
# 887       30.0
# 888      23.45
# 889       30.0
# 890       7.75
# Name: Fare, Length: 891, dtype: object

# %%
titanic['Fare_int'] = titanic.Fare.apply(int)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    Surname  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                   Other Names  Fare_int
# 0                             Mr. Owen Harris         7
# 1  Mrs. John Bradley (Florence Briggs Thayer)        71
# 2                                 Miss. Laina         7
# ...

# %%
def remove_title(name):
    name_list = name.split(' ')
    print(name_list)

# %%
remove_title('Mr Esther')
# Out:
# ['Mr', 'Esther']

# %%
remove_title('Mrs Esther Charlse')
# Out:
# ['Mrs', 'Esther', 'Charlse']

# %%
def remove_title(name):
    name_list = name.split(' ')
    return name_list[1]

# %%
remove_title('Mr Esther')
# Out:
# 'Esther'

# %%
remove_title('Mrs Esther Charlse')
# Out:
# 'Esther'

# %%
def remove_title(name):
    name_list = name.split(' ')
    return name_list[1:]

# %%
remove_title('Mr Esther')
# Out:
# ['Esther']

# %%
remove_title('Mrs Esther Charlse')
# Out:
# ['Esther', 'Charlse']

# %%
def remove_title(name):
    name_list = name.split(' ')
    return '+'.join(name_list[1:])

# %%
remove_title('Mrs Esther Charlse')
# Out:
# 'Esther+Charlse'

# %%
def remove_title(name):
    name_list = name.split(' ')
    return ' '.join(name_list[1:])

# %%
remove_title('Mrs Esther Charlse')
# Out:
# 'Esther Charlse'

# %%
titanic['Other Names'].apply(remove_title)
# Out:
# 0                                Owen Harris
# 1      John Bradley (Florence Briggs Thayer)
# 2                                      Laina
# 3              Jacques Heath (Lily May Peel)
# 4                              William Henry
#                        ...
# 886                                   Juozas
# 887                           Margaret Edith
# 888                 Catherine Helen "Carrie"
# 889                              Karl Howell
# 890                                  Patrick
# Name: Other Names, Length: 891, dtype: object
