# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('data_set/titanic/train.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Sex.map({'female': 0, 'male': 1})
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
titanic['Sex coded'] = titanic.Sex.map({'female': 0, 'male': 1})

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex coded
# 0      0         A/5 21171   7.2500   NaN        S          1
# 1      0          PC 17599  71.2833   C85        C          0
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0
# 3      0            113803  53.1000  C123        S          0
# ...

# %%
pd.get_dummies?
# Out:
# Signature:
# pd.get_dummies(
#     data,
#     prefix=None,
#     prefix_sep: 'str | Iterable[str] | dict[str, str]' = '_',
#     dummy_na: 'bool' = False,
#     columns=None,
#     sparse: 'bool' = False,
#     drop_first: 'bool' = False,
#     dtype: 'NpDtype | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Convert categorical variable into dummy/indicator variables.
#
# Each variable is converted in as many 0/1 variables as there are different
# values. Columns in the output are each named after a value; if the input is
# a DataFrame, the name of the original variable is prepended to the value.
#
# Parameters
# ----------
# data : array-like, Series, or DataFrame
#     Data of which to get dummy indicators.
# prefix : str, list of str, or dict of str, default None
#     String to append DataFrame column names.
#     Pass a list with length equal to the number of columns
#     when calling get_dummies on a DataFrame. Alternatively, `prefix`
# ...

# %%
pd.get_dummies(titanic, columns=['Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
pd.get_dummies(titanic, columns=['Sex']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Sex coded  Sex_female  Sex_male
# 0         A/5 21171   7.2500   NaN        S          1       False      True
# 1          PC 17599  71.2833   C85        C          0        True     False
# 2  STON/O2. 3101282   7.9250   NaN        S          0        True     False
# ...

# %%
pd.get_dummies(titanic, columns=['Sex'], drop_first=True).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Sex coded  Sex_male
# 0         A/5 21171   7.2500   NaN        S          1      True
# 1          PC 17599  71.2833   C85        C          0     False
# 2  STON/O2. 3101282   7.9250   NaN        S          0     False
# ...

# %%
pd.get_dummies(titanic, columns=['Sex'], prefix='gender', prefix_sep=' ').head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Sex coded  gender female  \
# 0         A/5 21171   7.2500   NaN        S          1          False
# 1          PC 17599  71.2833   C85        C          0           True
# 2  STON/O2. 3101282   7.9250   NaN        S          0           True
# ...

# %%
pd.get_dummies(titanic, columns=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.plot?
# Out:
# Signature:      titanic.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x0000013F12885150>
# File:           c:\users\oxward\appdata\local\programs\python\python311\lib\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
# ...

# %%
titanic.Sex.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 titanic.Sex.plot()
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
titanic.Sex.plot(kind= 'bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 titanic.Sex.plot(kind= 'bar')
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
titanic.Age.plot()
# Out:
# <Axes: >

# %%
titanic.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic.Sex.value_counts().plot()
# Out:
# <Axes: xlabel='Sex'>

# %%
titanic.Sex.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
titanic.Sex.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
titanic.Sex.value_counts().plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic.Sex.value_counts().plot(kind = 'Scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 titanic.Sex.value_counts().plot(kind = 'Scatter')
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:964, in PlotAccessor.__call__(self, *args, **kwargs)
#     961     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     963 if kind not in self._all_kinds:
# --> 964     raise ValueError(f"{kind} is not a valid plot kind")
#     966 # The original data structured can be transformed before passed to the
#     967 # backend. For example, for DataFrame is common to set the index as the
#     968 # `x` parameter, and return a Series with the parameter `y` as values.
#     969 data = self._parent.copy()
#
# ValueError: Scatter is not a valid plot kind

# %%
titanic.Age.plot(kind = 'Scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 titanic.Age.plot(kind = 'Scatter')
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:964, in PlotAccessor.__call__(self, *args, **kwargs)
#     961     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     963 if kind not in self._all_kinds:
# --> 964     raise ValueError(f"{kind} is not a valid plot kind")
#     966 # The original data structured can be transformed before passed to the
#     967 # backend. For example, for DataFrame is common to set the index as the
#     968 # `x` parameter, and return a Series with the parameter `y` as values.
#     969 data = self._parent.copy()
#
# ValueError: Scatter is not a valid plot kind

# %%
titanic.plot(kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 titanic.plot(kind = 'scatter')
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:976, in PlotAccessor.__call__(self, *args, **kwargs)
#     974 if kind in self._dataframe_kinds:
#     975     if isinstance(data, ABCDataFrame):
# --> 976         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     977     else:
#     978         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\Users\Oxward\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
titanic.plot?
# Out:
# Signature:      titanic.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x0000013F12885150>
# File:           c:\users\oxward\appdata\local\programs\python\python311\lib\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
# ...

# %%
titanic.Age.plot(kind = 'box')
# Out:
# <Axes: >

# %%
titanic.Fare.plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## Data Scalling

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare   Sex coded
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.647587
# std      0.806057   49.693429    0.477990
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    1.000000
# 75%      0.000000   31.000000    1.000000
# ...
